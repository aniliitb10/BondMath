# %%
import pandas as pd
import numpy as np

# %%
def get_df_from_auction_string(auction_str: str) -> pd.DataFrame:
    rows = t_bill_auction.replace('\t', ',').replace('%', '').replace('$', '').replace('-Week', '').split('\n')
    rows  = [row for row in rows if row]

    data = [row.split(',') for row in rows]
    df = pd.DataFrame(columns=[col.strip() for col in data[0]], data=data[1:])
    df = df.astype({"Bills" : 'int64', "Issue Date":'datetime64[ns]', 'High Rate': 'float64',
                    'Investment Rate': 'float64', 'Price per 100': 'float64'})
    df.rename(columns={'Bills': 'Maturity'}, inplace=True)
    return df

# %%
t_bill_auction = """
Bills 	CMB 	CUSIP 	Issue Date 	High Rate 	Investment Rate 	Price per $100
4-Week	No	912797HD2	10/03/2023	5.290%	5.400%	$99.588556
8-Week	No	912797HM2	10/03/2023	5.330%	5.464%	$99.170889
13-Week	No	912796ZN2	09/28/2023	5.330%	5.493%	$98.652694
17-Week	No	912797JB4	10/03/2023	5.345%	5.532%	$98.233181
26-Week	No	912797GY7	09/28/2023	5.315%	5.553%	$97.312972
52-Week	No	912797GL5	09/07/2023	5.120%	5.417%	$94.823111
"""

# %%
df = get_df_from_auction_string(t_bill_auction)
df
# Out:
#    Maturity CMB      CUSIP Issue Date  High Rate  Investment Rate  \
# 0         4  No  912797HD2 2023-10-03      5.290            5.400
# 1         8  No  912797HM2 2023-10-03      5.330            5.464
# 2        13  No  912796ZN2 2023-09-28      5.330            5.493
# 3        17  No  912797JB4 2023-10-03      5.345            5.532
# 4        26  No  912797GY7 2023-09-28      5.315            5.553
# 5        52  No  912797GL5 2023-09-07      5.120            5.417
#
#    Price per 100
# 0      99.588556
# 1      99.170889
# 2      98.652694
# 3      98.233181
# 4      97.312972
# 5      94.823111

# %%
df.dtypes
# Out:
# Maturity                    int64
# CMB                        object
# CUSIP                      object
# Issue Date         datetime64[ns]
# High Rate                 float64
# Investment Rate           float64
# Price per 100             float64
# dtype: object

# %% [markdown]
# ## Calculate Price from Discount Rates
# Price can be calculated using:
# $$
# Price = 100 \times (1 - \frac {\text{Discount rate}}{100} \times \frac{\text {Maturity in days}}{\text {Days in year}})
# $$

# %%
df['Calculated Price'] = 100 * (1 - (df['High Rate'] / 100 ) * (df['Maturity'] / 52))
df['Check Caclulated Price'] =  np.isclose(df['Price per 100'], df['Calculated Price'], atol=0.001)
df
# Out:
#    Maturity CMB      CUSIP Issue Date  High Rate  Investment Rate  \
# 0         4  No  912797HD2 2023-10-03      5.290            5.400
# 1         8  No  912797HM2 2023-10-03      5.330            5.464
# 2        13  No  912796ZN2 2023-09-28      5.330            5.493
# 3        17  No  912797JB4 2023-10-03      5.345            5.532
# 4        26  No  912797GY7 2023-09-28      5.315            5.553
# 5        52  No  912797GL5 2023-09-07      5.120            5.417
#
#    Price per 100  Calculated Price  Check Caclulated Price
# 0      99.588556         99.593077                   False
# 1      99.170889         99.180000                   False
# 2      98.652694         98.667500                   False
# 3      98.233181         98.252596                   False
# 4      97.312972         97.342500                   False
# 5      94.823111         94.880000                   False

# %% [markdown]
# ## Calculate Price from Discount Rates (360 Days)
# Price can be calculated using:
# $$
# Price = 100 \times (1 - \frac {\text{Discount rate}}{100} \times \frac{\text {Maturity in days}}{360})
# $$

# %%
df['Calculated Price'] = 100 * (1 - (df['High Rate'] / 100 ) * (df['Maturity'] * 7 / 360))
df['Check Caclulated Price'] =  np.isclose(df['Price per 100'], df['Calculated Price'], atol=0.001)
df
# Out:
#    Maturity CMB      CUSIP Issue Date  High Rate  Investment Rate  \
# 0         4  No  912797HD2 2023-10-03      5.290            5.400
# 1         8  No  912797HM2 2023-10-03      5.330            5.464
# 2        13  No  912796ZN2 2023-09-28      5.330            5.493
# 3        17  No  912797JB4 2023-10-03      5.345            5.532
# 4        26  No  912797GY7 2023-09-28      5.315            5.553
# 5        52  No  912797GL5 2023-09-07      5.120            5.417
#
#    Price per 100  Calculated Price  Check Caclulated Price
# 0      99.588556         99.588556                    True
# 1      99.170889         99.170889                    True
# 2      98.652694         98.652694                    True
# 3      98.233181         98.233181                    True
# 4      97.312972         97.312972                    True
# 5      94.823111         94.823111                    True

# %% [markdown]
# ### Calculate Investment Rate
# Investment rate can be caculates as:
#
# $$
# \text {Investment Rate} = \frac {\text {Face value - Buy price }}{\text {Buy price}} \times \frac {360}{\text {Maturity in days}}
# $$

# %%
df['Calculated Investment Rate'] = ((100 - df['Price per 100']) / df['Price per 100']) * (360 / (df['Maturity'] * 7)) * 100

df['Check Investment Rate'] =  np.isclose(df['Investment Rate'], df['Calculated Investment Rate'], atol=0.001)

# re-arrange columns and remove unnecesary columns
df.loc[:, ['Maturity', 'Issue Date', 'High Rate', 'Investment Rate', 'Calculated Investment Rate', 'Check Investment Rate',
                'Price per 100', 'Calculated Price', 'Check Caclulated Price']]
# Out:
#    Maturity Issue Date  High Rate  Investment Rate  \
# 0         4 2023-10-03      5.290            5.400
# 1         8 2023-10-03      5.330            5.464
# 2        13 2023-09-28      5.330            5.493
# 3        17 2023-10-03      5.345            5.532
# 4        26 2023-09-28      5.315            5.553
# 5        52 2023-09-07      5.120            5.417
#
#    Calculated Investment Rate  Check Investment Rate  Price per 100  \
# 0                    5.311850                  False      99.588556
# 1                    5.374560                  False      99.170889
# 2                    5.402794                  False      98.652694
# 3                    5.441134                  False      98.233181
# 4                    5.461759                  False      97.312972
# 5                    5.399528                  False      94.823111
#
#    Calculated Price  Check Caclulated Price
# 0         99.588556                    True
# 1         99.170889                    True
# 2         98.652694                    True
# 3         98.233181                    True
# 4         97.312972                    True
# 5         94.823111                    True

# %% [markdown]
# ### Calculate Investment Rate (366 days)
# Investment rate can be caculates as:
#
# $$
# \text {Investment Rate} = \frac {\text {Face value - Buy price }}{\text {Buy price}} \times \frac {366}{\text {Maturity in days}}
# $$

# %%
df['Calculated Investment Rate'] = ((100 - df['Price per 100']) / df['Price per 100']) * (366 / (df['Maturity'] * 7)) * 100

df['Check Investment Rate'] =  np.isclose(df['Investment Rate'], df['Calculated Investment Rate'], atol=0.001)

df.loc[:, ['Maturity', 'Issue Date', 'High Rate', 'Investment Rate', 'Calculated Investment Rate', 'Check Investment Rate',
                'Price per 100', 'Calculated Price', 'Check Caclulated Price']]
# Out:
#    Maturity Issue Date  High Rate  Investment Rate  \
# 0         4 2023-10-03      5.290            5.400
# 1         8 2023-10-03      5.330            5.464
# 2        13 2023-09-28      5.330            5.493
# 3        17 2023-10-03      5.345            5.532
# 4        26 2023-09-28      5.315            5.553
# 5        52 2023-09-07      5.120            5.417
#
#    Calculated Investment Rate  Check Investment Rate  Price per 100  \
# 0                    5.400380                   True      99.588556
# 1                    5.464136                   True      99.170889
# 2                    5.492840                   True      98.652694
# 3                    5.531819                   True      98.233181
# 4                    5.552789                   True      97.312972
# 5                    5.489520                  False      94.823111
#
#    Calculated Price  Check Caclulated Price
# 0         99.588556                    True
# 1         99.170889                    True
# 2         98.652694                    True
# 3         98.233181                    True
# 4         97.312972                    True
# 5         94.823111                    True

# %% [markdown]
# ### Periodicity
# For any bond's maturity, it is the number of such maturity periods in an year. Equating the ratio of Future Value and Present Value for different periodicities, m and n:
#
# $$
# \Bigg( 1 + \frac{APR_n}{n}\Bigg) ^n = \Bigg( 1 + \frac{APR_m}{m}\Bigg) ^m
# $$
#
# $$
# 1 + \frac{APR_n}{n} = \Bigg( \bigg( 1 + \frac{APR_m}{m}\bigg) ^m \Bigg)^\frac{1}{n}
# $$
#
# $$
# \frac{APR_n}{n} = \Bigg( \bigg( 1 + \frac{APR_m}{m}\bigg) ^m \Bigg)^\frac{1}{n} - 1
# $$
#
# $$
# APR_n = \Bigg( \bigg( \Big( 1 + \frac{APR_m}{m}\Big) ^m \bigg)^\frac{1}{n} - 1 \Bigg) \times n
# $$

# %%
import math
def change_periodicity(*, rate: float, old: int, new: int) -> float:
    return (math.pow(math.pow((1 + rate / old), old), 1 / new) - 1) * new

# %%
change_periodicity(rate=df.at[5, 'Calculated Investment Rate']/100, old=1, new=2)*100
# Out:
# 5.416182216769583

# %%
# fixing the Calculated Investment Rate only for 52 week maturity
df.at[5, 'Calculated Investment Rate'] = change_periodicity(rate=df.at[5, 'Calculated Investment Rate']/100, old=1, new=2)*100
df['Check Investment Rate'] =  np.isclose(df['Investment Rate'], df['Calculated Investment Rate'], atol=0.001)
df.loc[:, ['Maturity', 'Issue Date', 'High Rate', 'Investment Rate', 'Calculated Investment Rate', 'Check Investment Rate',
                'Price per 100', 'Calculated Price']]
# Out:
#    Maturity Issue Date  High Rate  Investment Rate  \
# 0         4 2023-10-03      5.290            5.400
# 1         8 2023-10-03      5.330            5.464
# 2        13 2023-09-28      5.330            5.493
# 3        17 2023-10-03      5.345            5.532
# 4        26 2023-09-28      5.315            5.553
# 5        52 2023-09-07      5.120            5.417
#
#    Calculated Investment Rate  Check Investment Rate  Price per 100  \
# 0                    5.400380                   True      99.588556
# 1                    5.464136                   True      99.170889
# 2                    5.492840                   True      98.652694
# 3                    5.531819                   True      98.233181
# 4                    5.552789                   True      97.312972
# 5                    5.416182                   True      94.823111
#
#    Calculated Price
# 0         99.588556
# 1         99.170889
# 2         98.652694
# 3         98.233181
# 4         97.312972
# 5         94.823111

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Impact of Periodicity on Yield Curve
# * As the periodicity impacts the interest rate, it is an important factor to consider while comparing interest rates
# * 4 Week bond has periodicity of 13, 26 week bond has periodicity of 2 -> it is unfair to compare these interest rates values with different periodicities
# * Better to change the periodicity to the same value and then compare

# %%
# this is based on maturity, no special treatment for 52 weeks TBills
df['Calculated Investment Rate'] = ((100 - df['Price per 100']) / df['Price per 100']) * (366 / (df['Maturity'] * 7)) * 100

df['Investment Rate (Same Periodicity)'] = df.apply(
    lambda row: change_periodicity(rate=row['Calculated Investment Rate']/100, old=int(52/row['Maturity']), new=1)*100, axis=1
)

df.loc[:, ['Maturity', 'Issue Date', 'High Rate', 'Investment Rate', 'Investment Rate (Same Periodicity)',
           'Calculated Investment Rate', 'Price per 100', 'Calculated Price', ]]
# Out:
#    Maturity Issue Date  High Rate  Investment Rate  \
# 0         4 2023-10-03      5.290            5.400
# 1         8 2023-10-03      5.330            5.464
# 2        13 2023-09-28      5.330            5.493
# 3        17 2023-10-03      5.345            5.532
# 4        26 2023-09-28      5.315            5.553
# 5        52 2023-09-07      5.120            5.417
#
#    Investment Rate (Same Periodicity)  Calculated Investment Rate  \
# 0                            5.537056                    5.400380
# 1                            5.590061                    5.464136
# 2                            5.607022                    5.492840
# 3                            5.634450                    5.531819
# 4                            5.629872                    5.552789
# 5                            5.489520                    5.489520
#
#    Price per 100  Calculated Price
# 0      99.588556         99.588556
# 1      99.170889         99.170889
# 2      98.652694         98.652694
# 3      98.233181         98.233181
# 4      97.312972         97.312972
# 5      94.823111         94.823111

# %%
plt.plot(df['Maturity'], df['Investment Rate'], 'o-', label='Investment Rate on US Treasuries')
plt.plot(df['Maturity'], df['Calculated Investment Rate'], 'o-', label='Calculated Investment Rate')
plt.plot(df['Maturity'], df['Investment Rate (Same Periodicity)'], 'o-',label='Investment Rate (Same Periodicity)')
plt.legend()
plt.title('Yield Curve of Same Bonds with Different Periodicities')
plt.grid()
